# %%
print("hello")
# Out:
# hello

# %%
x=3
y=5
x+y
# Out:
# 8

# %% [markdown]
# <h1> welcome</h1>

# %%
x="1.2"
x==12
# Out:
# False

# %%
r='20f'

# %%
r2=r.rsplit('f')
r2
# Out:
# ['20', '']

# %%
a=2
b=4
c=a/b
c
# Out:
# 0.5

# %%
c1=a//b
c1
# Out:
# 0

# %%
c2=a%b
c2
# Out:
# 2

# %%
#data structures -list,tuple,dic,set
#list-collection of any datatype;[];mutable
lst=['apple','mango','grapes','watermelon','papaya','jack fruit']
lst
# Out:
# ['apple', 'mango', 'grapes', 'watermelon', 'papaya', 'jack fruit']

# %%
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
lst.insert(4,'orange')

# %%
lst.pop(-2)
# Out:
# 'papaya'

# %%
lst
# Out:
# ['apple', 'mango', 'grapes', 'watermelon', 'orange', 'jack fruit']

# %%
lst.reverse()

# %%
lst
# Out:
# ['jack fruit', 'orange', 'watermelon', 'grapes', 'mango', 'apple']

# %%
lst.clear()

# %%
lst
# Out:
# []

# %%
#tuple immutable|()
tup=('aiems',15,'bidadi',562109.0)
tup
# Out:
# ('aiems', 15, 'bidadi', 562109.0)

# %%
dir(tuple)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
#set - no duplicates,{}
st={1,2,3,4,5,6,000}
st
# Out:
# {0, 1, 2, 3, 4, 5, 6}

# %%
dir(set)
# Out:
# ['__and__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iand__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__isub__',
#  '__iter__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__rand__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__ror__',
#  '__rsub__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__xor__',
#  'add',
#  'clear',
#  'copy',
#  'difference',
#  'difference_update',
#  'discard',
#  'intersection',
#  'intersection_update',
#  'isdisjoint',
#  'issubset',
#  'issuperset',
#  'pop',
#  'remove',
#  'symmetric_difference',
#  'symmetric_difference_update',
#  'union',
#  'update']

# %%
st1={6,7,8,4,2,34,}
st1
# Out:
# {2, 4, 6, 7, 8, 34}

# %%
st.union(st1)
st.intersection(st1)
# Out:
# {2, 4, 6}

# %%
#dictionary- k:v|{}| keys are always unique
di={'name':'shravani','age':23}
di
# Out:
# {'name': 'shravani', 'age': 23}

# %%
dir(dict)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
di.values()
# Out:
# dict_values(['shravani', 23])

# %%
di.keys()
# Out:
# dict_keys(['name', 'age'])

# %%
'''
guygqgwhjg
sghjgh
sjbhjegh
'''
# Out:
# '\nguygqgwhjg\nsghjgh\nsjbhjegh\n'

# %%
#condition statments
#if condition
x=10
if x>=10:
    print('True!')
else:
    print('False!')
# Out:
# True!

# %%
marks=55
if marks>=90:
    print('A+')
elif marks >=70 and marks <=89:
    print('A')
elif marks >=60 and marks <=69:
    print('B')
else:
    print('c')
# Out:
# c

# %%
for i in range(9):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8

# %%
for a in range(0,11,2):
 print(a)
# Out:
# 0
# 2
# 4
# 6
# 8
# 10

# %%
for a1 in range(1,11,2):
 print(a1)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
#while loop
count=5
while count >=0:
    print(count)
    count=count-1
# Out:
# 5
# 4
# 3
# 2
# 1
# 0

# %%
for i in range(5):
    if i==3:
        continue
    print(i)
# Out:
# 0
# 1
# 2
# 4

# %%
def funcname():
    return

# %%
def addation(a,b):
    return a+b
addation(4,5)
# Out:
# 9

# %%
def add2(*args):
    return sum(args)
add2(2,3,4,5,6,7,8,9)
# Out:
# 44

# %%
def greet1():
   print('hello')
greet1
# Out:
# <function __main__.greet1()>

# %%
# to install library
# %pip install pandas numpy matplotlib seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#data analytics
#improting thr libraries
import pandas as pd
import numpy as np

# %%
#load the data set


df = pd.read_csv('Student_Behaviour.csv')
df.head()
# Out:
#   Certification Course  Gender Department  Height(CM)  Weight(KG)  10th Mark  \
# 0                   No    Male        BCA       100.0        58.0       79.0
# 1                   No  Female        BCA        90.0        40.0       70.0
# 2                  Yes    Male        BCA       159.0        78.0       69.5
# 3                  Yes  Female        BCA       147.0        20.0       70.0
# 4                   No    Male        BCA       170.0        54.0       40.0
#
#    12th Mark  college mark        hobbies daily studing time  \
# 0       65.0          80.0    Video Games      0 - 30 minute
# 1       80.0          70.0         Cinema     30 - 60 minute
# 2       61.0          55.0         Cinema         1 - 2 Hour
# 3       59.0          58.0  Reading books         1 - 2 Hour
# 4       65.0          30.0    Video Games     30 - 60 minute
#
#   prefer to study in  salary expectation Do you like your degree?  \
# ...

# %%
df = pd.read_csv('Student_Behaviour.csv')
df.tail(11)
# Out:
#     Certification Course  Gender Department  Height(CM)  Weight(KG)  \
# 224                  Yes  Female   Commerce       152.0        65.0
# 225                  Yes  Female   Commerce       164.0        43.0
# 226                  Yes  Female   Commerce       167.0        65.0
# 227                  Yes    Male  B.com ISM       167.0        55.0
# 228                  Yes    Male  B.com ISM       155.0        68.0
# 229                   No  Female  B.com ISM       153.0        60.0
# 230                  Yes    Male  B.com ISM       170.0        76.0
# 231                  Yes    Male  B.com ISM       172.0        52.0
# 232                  Yes  Female        BCA       139.0        33.0
# 233                  Yes  Female   Commerce       153.0        58.0
# 234                   No  Female  B.com ISM       155.0        39.0
#
#      10th Mark  12th Mark  college mark        hobbies daily studing time  \
# 224       97.0       80.0         100.0  Reading books         3 - 4 hour
# ...

# %%
#to know rows and clm
df.shape
# Out:
# (235, 19)

# %%
print ('the no. of rows:{def.shape[0]} and cols:{def.shape[1]}')
# Out:
# the no. of rows:{def.shape[0]} and cols:{def.shape[1]}

# %%
df.info
# Out:
# <bound method DataFrame.info of     Certification Course  Gender Department  Height(CM)  Weight(KG)  \
# 0                     No    Male        BCA       100.0        58.0
# 1                     No  Female        BCA        90.0        40.0
# 2                    Yes    Male        BCA       159.0        78.0
# 3                    Yes  Female        BCA       147.0        20.0
# 4                     No    Male        BCA       170.0        54.0
# ..                   ...     ...        ...         ...         ...
# 230                  Yes    Male  B.com ISM       170.0        76.0
# 231                  Yes    Male  B.com ISM       172.0        52.0
# 232                  Yes  Female        BCA       139.0        33.0
# 233                  Yes  Female   Commerce       153.0        58.0
# 234                   No  Female  B.com ISM       155.0        39.0
#
#      10th Mark  12th Mark  college mark        hobbies daily studing time  \
# ...

# %%
df.describe()
# Out:
#        Height(CM)  Weight(KG)   10th Mark   12th Mark  college mark  \
# count  235.000000  235.000000  235.000000  235.000000    235.000000
# mean   157.402128   60.803830   76.842128   68.780128     70.660553
# std     21.510805   14.895844   13.050800   11.016533     15.727446
# min      4.500000   20.000000    7.400000   45.000000      1.000000
# 25%    152.000000   50.000000   70.000000   60.000000     60.000000
# 50%    160.000000   60.000000   80.000000   69.000000     70.000000
# 75%    170.000000   70.000000   86.250000   76.000000     80.000000
# max    192.000000  106.000000   98.000000   94.000000    100.000000
#
#        salary expectation
# count        2.350000e+02
# mean         3.248168e+04
# std          1.113146e+05
# min          0.000000e+00
# 25%          1.500000e+04
# 50%          2.000000e+04
# 75%          2.500000e+04
# max          1.500000e+06

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('Student_Behaviour.csv')
df.head()
# Out:
#   Certification Course  Gender Department  Height(CM)  Weight(KG)  10th Mark  \
# 0                   No    Male        BCA       100.0        58.0       79.0
# 1                   No  Female        BCA        90.0        40.0       70.0
# 2                  Yes    Male        BCA       159.0        78.0       69.5
# 3                  Yes  Female        BCA       147.0        20.0       70.0
# 4                   No    Male        BCA       170.0        54.0       40.0
#
#    12th Mark  college mark        hobbies daily studing time  \
# 0       65.0          80.0    Video Games      0 - 30 minute
# 1       80.0          70.0         Cinema     30 - 60 minute
# 2       61.0          55.0         Cinema         1 - 2 Hour
# 3       59.0          58.0  Reading books         1 - 2 Hour
# 4       65.0          30.0    Video Games     30 - 60 minute
#
#   prefer to study in  salary expectation Do you like your degree?  \
# ...

# %%
df.columns
# Out:
# Index(['Certification Course', 'Gender', 'Department', 'Height(CM)',
#        'Weight(KG)', '10th Mark', '12th Mark', 'college mark', 'hobbies',
#        'daily studing time', 'prefer to study in', 'salary expectation',
#        'Do you like your degree?',
#        'willingness to pursue a career based on their degree  ',
#        'social medai & video', 'Travelling Time ', 'Stress Level ',
#        'Financial Status', 'part-time job'],
#       dtype='object')

# %%
df.Gender
# Out:
# 0        Male
# 1      Female
# 2        Male
# 3      Female
# 4        Male
#         ...
# 230      Male
# 231      Male
# 232    Female
# 233    Female
# 234    Female
# Name: Gender, Length: 235, dtype: object

# %%
df.iloc[2:5,1:3]
# Out:
#    Gender Department
# 2    Male        BCA
# 3  Female        BCA
# 4    Male        BCA
